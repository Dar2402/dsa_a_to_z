# %%
{
    "agent_email_id": "developer_002@grr.la",
    "bot_id": "SpXUeBA_zrbh",
    "current_session_id": "2611251764754730",
    "user_id": "1763979420000",
    "session_id": "7eeba453-f18c-48fa-b2ac-cbe1928612e2",
    "chat_count": 20,
    "last_timestamp": "2025-11-26T07:58:23.746Z",
    "transcript": false
}

# %%
{'event': 'fetch_agent_session_details_end', 'agent_email_id': 'developer_002@grr.la', 'result_found': True, 'result': {'agent_session_id': '6294edfa-c23f-4ace-a0a2-db2cf5a30a30', 'created_at': datetime.datetime(2025, 11, 26, 6, 7, 34, 900000), 'last_updated': datetime.datetime(2025, 11, 26, 8, 18, 34, 142000), 'agent_name': 'Developer Frontend 2', 'agent_email_id': 'developer_002@grr.la', 'room_id': 'developer_002@grr.la', 'bot_id': 'SpXUeBA', 'agent_team': ['Frontend Team'], 'agent_int_id': 'SpXUeBA_RIFV', 'agent_int_name': 'DEVELOPER BOTLive Chat', 'max_chat_count': 3, 'current_chat_count': 2, 'available_chats': 1, 'is_available': True, 'on_break': False, 'chatting_with': ['7eeba453-f18c-48fa-b2ac-cbe1928612e2', '079d1189-3e98-4a71-84fd-28aa7d9aba61'], 'role': 'User', 'agent_lang_code': 'ar', 'total_email_count': 0, 'unread_email_count': 0}, 'timestamp': '2025-11-26T09:38:20.319253'}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ...
